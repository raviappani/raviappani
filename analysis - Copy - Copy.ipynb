# %%
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

# %%
df=pd.read_csv("cars_24original")

# %%
def extract(x):
    if x<500000:
        return "Low"
    elif x<1000000:
        return "Medium"
    elif x<1500000:
        return "High"
    else:
        return "Very High"

# %%
df["Price_level"]=df["Original_Price"].apply(extract)

# %%
df["Price_level"].value_counts()
# Out:
# Low          239
# Medium       179
# High          15
# Very High      7
# Name: Price_level, dtype: int64

# %%
df.to_csv("ravi24",index=False)

# %%
df
# Out:
#     Name_of_Car  Original_Price  Offer_Price Type_of_Fuel       Ride  Year  \
# 0        Maruti          144000       144000       Petrol     Manual  2010
# 1        Maruti          150000       141000       Petrol     Manual  2010
# 2        Maruti          153000       137000       Petrol     Manual  2010
# 3        Maruti          156000       156000       Petrol     Manual  2011
# 4        Maruti          161000       156000       Petrol     Manual  2011
# ..          ...             ...          ...          ...        ...   ...
# 435          MG         1602000      1541000       Diesel     Manual  2020
# 436         KIA         1734000      1734000       Diesel  Automatic  2022
# 437         KIA         1800000      1800000       Diesel     Manual  2022
# 438       Skoda         1901000      1828000       Petrol  Automatic  2022
# 439      Toyota         2297000      2214000       Diesel  Automatic  2017
#
# ...

# %%
df.drop(["max"],axis=1,inplace=True)

# %%
df
# Out:
#     Name_of_Car  Original_Price  Offer_Price Type_of_Fuel       Ride  Year  \
# 0        Maruti          144000       144000       Petrol     Manual  2010
# 1        Maruti          150000       141000       Petrol     Manual  2010
# 2        Maruti          153000       137000       Petrol     Manual  2010
# 3        Maruti          156000       156000       Petrol     Manual  2011
# 4        Maruti          161000       156000       Petrol     Manual  2011
# ..          ...             ...          ...          ...        ...   ...
# 435          MG         1602000      1541000       Diesel     Manual  2020
# 436         KIA         1734000      1734000       Diesel  Automatic  2022
# 437         KIA         1800000      1800000       Diesel     Manual  2022
# 438       Skoda         1901000      1828000       Petrol  Automatic  2022
# 439      Toyota         2297000      2214000       Diesel  Automatic  2017
#
# ...

# %%
df.shape
# Out:
# (440, 13)

# %%
df.isnull().sum()
# Out:
# Name_of_Car       0
# Original_Price    0
# Offer_Price       0
# Type_of_Fuel      0
# Ride              0
# Year              0
# KM(ran)           0
# car_type          0
# EMI(per/month)    0
# downpayment       0
# city              0
# Price_level       0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.dtypes
# Out:
# Name_of_Car       object
# Original_Price     int64
# Offer_Price        int64
# Type_of_Fuel      object
# Ride              object
# Year               int64
# KM(ran)            int64
# car_type          object
# EMI(per/month)     int64
# downpayment        int64
# city              object
# Price_level       object
# dtype: object

# %%
df["Name_of_Car"].value_counts()
# Out:
# Maruti        172
# Hyundai        95
# Tata           30
# Honda          29
# Renault        29
# Mahindra       19
# Volkswagen     17
# Toyota         13
# Datsun          8
# Skoda           8
# Ford            6
# KIA             5
# Nissan          4
# Jeep            4
# MG              1
# Name: Name_of_Car, dtype: int64

# %%
sns.countplot(x="Name_of_Car",data=df)
plt.xticks(rotation=90)
plt.show()

# %%
df["city"].value_counts()
# Out:
# Ahmedabad          20
# LasudiaMori        20
# Surat              20
# Rajkot             20
# Patna              20
# Nasik              20
# Nagpur             20
# Coimbatore         20
# Agra               20
# Pune               20
# Lucknow            20
# Kolkata            20
# Mansarovar         20
# Kochi              20
# Hyderabad          20
# Vadodara           20
# Bengaluru          19
# Chennai            19
# Chandigarh         18
# Faridabad          18
# Mulund             11
# Mumbai              9
# Gurugram            7
# NewDelhi            6
# Rohtak              5
# Ludhiana            2
# Noida               2
# Ghaziabad           2
# Navalur             1
# Sonnappanahalli     1
# Name: city, dtype: int64

# %%
sns.countplot(x=df["city"],data=df)
plt.xticks(rotation=90)
plt.show()

# %%
df["Ride"].value_counts()
# Out:
# Manual       390
# Automatic     50
# Name: Ride, dtype: int64

# %%
plt.pie(df["Ride"].value_counts(),labels=df["Ride"].unique(),autopct="%1.1f%%",shadow=True,explode=[0.2,0])
plt.show()

# %%
df["Type_of_Fuel"].value_counts()
# Out:
# Petrol    307
# Diesel    102
# CNG        31
# Name: Type_of_Fuel, dtype: int64

# %%
plt.pie(df["Type_of_Fuel"].value_counts(),labels=df["Type_of_Fuel"].unique(),autopct="%1.1f%%")
plt.show()

# %%
df["car_type"].value_counts()
# Out:
# 1st    276
# 2nd    137
# 3rd     26
# 4th      1
# Name: car_type, dtype: int64

# %%
sns.countplot(x=df["car_type"])
plt.xticks(rotation=90)
plt.show()

# %%
df.head()
# Out:
#   Name_of_Car  Original_Price  Offer_Price Type_of_Fuel    Ride  Year  \
# 0      Maruti          144000       144000       Petrol  Manual  2010
# 1      Maruti          150000       141000       Petrol  Manual  2010
# 2      Maruti          153000       137000       Petrol  Manual  2010
# 3      Maruti          156000       156000       Petrol  Manual  2011
# 4      Maruti          161000       156000       Petrol  Manual  2011
#
#    KM(ran) car_type  EMI(per/month)  downpayment       city Price_level
# 0    61662      1st            5693        28800      Patna         Low
# 1    54501      1st            3488        28200    Kolkata         Low
# 2    76672      3rd            2502        27400    Kolkata         Low
# 3    63904      2nd            6850        31200  Ahmedabad         Low
# 4    29904      2nd            2690        31200     Nagpur         Low

# %%
df=df.sort_values(["Original_Price","Offer_Price"]).reset_index(drop=True)

# %%
df
# Out:
#     Name_of_Car  Original_Price  Offer_Price Type_of_Fuel       Ride  Year  \
# 0        Maruti          144000       144000       Petrol     Manual  2010
# 1        Maruti          150000       141000       Petrol     Manual  2010
# 2        Maruti          153000       137000       Petrol     Manual  2010
# 3        Maruti          156000       156000       Petrol     Manual  2011
# 4        Maruti          161000       156000       Petrol     Manual  2011
# ..          ...             ...          ...          ...        ...   ...
# 435          MG         1602000      1541000       Diesel     Manual  2020
# 436         KIA         1734000      1734000       Diesel  Automatic  2022
# 437         KIA         1800000      1800000       Diesel     Manual  2022
# 438       Skoda         1901000      1828000       Petrol  Automatic  2022
# 439      Toyota         2297000      2214000       Diesel  Automatic  2017
#
#      KM(ran) car_type  EMI(per/month)  downpayment       city
# ...

# %%
df_1st=df[df["car_type"]=="1st" ].reset_index(drop=True)

# %%
df_1st
# Out:
#     Name_of_Car  Original_Price  Offer_Price Type_of_Fuel       Ride  Year  \
# 0        Maruti          144000       144000       Petrol     Manual  2010
# 1        Maruti          150000       141000       Petrol     Manual  2010
# 2       Hyundai          162000       129000       Petrol     Manual  2011
# 3        Maruti          163000       148000       Petrol     Manual  2010
# 4        Maruti          170000       170000          CNG     Manual  2011
# ..          ...             ...          ...          ...        ...   ...
# 271    Mahindra         1569000      1521000       Diesel     Manual  2022
# 272          MG         1602000      1541000       Diesel     Manual  2020
# 273         KIA         1734000      1734000       Diesel  Automatic  2022
# 274         KIA         1800000      1800000       Diesel     Manual  2022
# 275       Skoda         1901000      1828000       Petrol  Automatic  2022
#
#      KM(ran) car_type  EMI(per/month)  downpayment       city
# ...

# %%
sns.lineplot(data=df_1st,x=df_1st["Original_Price"],y=df_1st["Offer_Price"])
plt.show()

# %%
sns.scatterplot(data=df_1st,x=df_1st["Original_Price"],y=df_1st["Offer_Price"])
plt.show()

# %%
sns.lineplot(data=df_1st,x=df_1st["Original_Price"],y=df_1st["Offer_Price"],hue=df_1st["car_type"])
plt.show()

# %%
sns.lineplot(data=df,x=df["Original_Price"],y=df["Offer_Price"],hue=df["car_type"])
plt.show()

# %%
sns.scatterplot(data=df,x=df["Original_Price"],y=df["Offer_Price"],hue=df["car_type"])
plt.show()

# %%
df_2nd=df[df["car_type"]=="2nd" ].reset_index(drop=True)

# %%
df_2nd
# Out:
#     Name_of_Car  Original_Price  Offer_Price Type_of_Fuel       Ride  Year  \
# 0        Maruti          156000       156000       Petrol     Manual  2011
# 1        Maruti          161000       156000       Petrol     Manual  2011
# 2        Maruti          162000       149000       Petrol     Manual  2010
# 3        Maruti          179000       160000       Petrol     Manual  2010
# 4        Maruti          186000       181000       Petrol     Manual  2010
# ..          ...             ...          ...          ...        ...   ...
# 132      Toyota          939000       891000       Diesel     Manual  2014
# 133     Hyundai         1040000      1040000       Petrol     Manual  2020
# 134    Mahindra         1065000      1026000       Diesel     Manual  2019
# 135         KIA         1166000      1082000       Petrol  Automatic  2019
# 136        Jeep         1334000      1282000       Petrol  Automatic  2018
#
#      KM(ran) car_type  EMI(per/month)  downpayment        city
# ...

# %%
df["car_type"].value_counts()
# Out:
# 1st    276
# 2nd    137
# 3rd     26
# 4th      1
# Name: car_type, dtype: int64

# %%
##

# %%
df_3rd=df[df["car_type"]=="3rd" ].reset_index(drop=True)

# %%
df_3rd
# Out:
#    Name_of_Car  Original_Price  Offer_Price Type_of_Fuel       Ride  Year  \
# 0       Maruti          153000       137000       Petrol     Manual  2010
# 1      Hyundai          188000       172000       Petrol     Manual  2010
# 2      Hyundai          218000       218000       Petrol     Manual  2014
# 3   Volkswagen          225000       215000       Petrol     Manual  2011
# 4       Maruti          250000       237000       Petrol     Manual  2011
# 5       Maruti          259000       250000          CNG     Manual  2015
# 6       Maruti          263000       239000       Petrol     Manual  2012
# 7       Maruti          280000       227000       Petrol     Manual  2016
# 8        Honda          287000       268000       Petrol     Manual  2013
# 9      Hyundai          295000       215000       Petrol     Manual  2012
# 10     Hyundai          304000       253000       Diesel     Manual  2015
# 11      Maruti          308000       276000       Petrol     Manual  2011
# ...

# %%
df_4th=df[df["car_type"]=="4th" ].reset_index(drop=True)

# %%
df_4th
# Out:
#   Name_of_Car  Original_Price  Offer_Price Type_of_Fuel    Ride  Year  \
# 0      Toyota          683000       619000       Diesel  Manual  2013
#
#    KM(ran) car_type  EMI(per/month)  downpayment    city
# 0    67882      4th            8300       123800  Mulund

# %%
df_1st.head()
# Out:
#   Name_of_Car  Original_Price  Offer_Price Type_of_Fuel    Ride  Year  \
# 0      Maruti          144000       144000       Petrol  Manual  2010
# 1      Maruti          150000       141000       Petrol  Manual  2010
# 2     Hyundai          162000       129000       Petrol  Manual  2011
# 3      Maruti          163000       148000       Petrol  Manual  2010
# 4      Maruti          170000       170000          CNG  Manual  2011
#
#    KM(ran) car_type  EMI(per/month)  downpayment      city
# 0    61662      1st            5693        28800     Patna
# 1    54501      1st            3488        28200   Kolkata
# 2    94852      1st           11151        25800     Patna
# 3    91626      1st            4489        29600     Kochi
# 4    82340      1st            8899        34000  Vadodara

# %%
df_2nd.head()
# Out:
#   Name_of_Car  Original_Price  Offer_Price Type_of_Fuel    Ride  Year  \
# 0      Maruti          156000       156000       Petrol  Manual  2011
# 1      Maruti          161000       156000       Petrol  Manual  2011
# 2      Maruti          162000       149000       Petrol  Manual  2010
# 3      Maruti          179000       160000       Petrol  Manual  2010
# 4      Maruti          186000       181000       Petrol  Manual  2010
#
#    KM(ran) car_type  EMI(per/month)  downpayment       city
# 0    63904      2nd            6850        31200  Ahmedabad
# 1    29904      2nd            2690        31200     Nagpur
# 2    59489      2nd            5508        29800     Mumbai
# 3    71156      2nd            5208        32000    Kolkata
# 4    61569      2nd            8805        36200   NewDelhi

# %%
df
# Out:
#     Name_of_Car  Original_Price  Offer_Price Type_of_Fuel       Ride  Year  \
# 0        Maruti          144000       144000       Petrol     Manual  2010
# 1        Maruti          150000       141000       Petrol     Manual  2010
# 2        Maruti          153000       137000       Petrol     Manual  2010
# 3        Maruti          156000       156000       Petrol     Manual  2011
# 4        Maruti          161000       156000       Petrol     Manual  2011
# ..          ...             ...          ...          ...        ...   ...
# 435          MG         1602000      1541000       Diesel     Manual  2020
# 436         KIA         1734000      1734000       Diesel  Automatic  2022
# 437         KIA         1800000      1800000       Diesel     Manual  2022
# 438       Skoda         1901000      1828000       Petrol  Automatic  2022
# 439      Toyota         2297000      2214000       Diesel  Automatic  2017
#
#      KM(ran) car_type  EMI(per/month)  downpayment       city
# ...

# %%
#df.drop(["1st_max"],axis=1,inplace=True)

# %%
df
# Out:
#     Name_of_Car  Original_Price  Offer_Price Type_of_Fuel       Ride  Year  \
# 0        Maruti          144000       144000       Petrol     Manual  2010
# 1        Maruti          150000       141000       Petrol     Manual  2010
# 2        Maruti          153000       137000       Petrol     Manual  2010
# 3        Maruti          156000       156000       Petrol     Manual  2011
# 4        Maruti          161000       156000       Petrol     Manual  2011
# ..          ...             ...          ...          ...        ...   ...
# 435          MG         1602000      1541000       Diesel     Manual  2020
# 436         KIA         1734000      1734000       Diesel  Automatic  2022
# 437         KIA         1800000      1800000       Diesel     Manual  2022
# 438       Skoda         1901000      1828000       Petrol  Automatic  2022
# 439      Toyota         2297000      2214000       Diesel  Automatic  2017
#
#      KM(ran) car_type  EMI(per/month)  downpayment       city
# ...

# %%
df["max"]=df.groupby("Name_of_Car")['Original_Price'].transform("max")

# %%
df
# Out:
#     Name_of_Car  Original_Price  Offer_Price Type_of_Fuel       Ride  Year  \
# 0        Maruti          144000       144000       Petrol     Manual  2010
# 1        Maruti          150000       141000       Petrol     Manual  2010
# 2        Maruti          153000       137000       Petrol     Manual  2010
# 3        Maruti          156000       156000       Petrol     Manual  2011
# 4        Maruti          161000       156000       Petrol     Manual  2011
# ..          ...             ...          ...          ...        ...   ...
# 435          MG         1602000      1541000       Diesel     Manual  2020
# 436         KIA         1734000      1734000       Diesel  Automatic  2022
# 437         KIA         1800000      1800000       Diesel     Manual  2022
# 438       Skoda         1901000      1828000       Petrol  Automatic  2022
# 439      Toyota         2297000      2214000       Diesel  Automatic  2017
#
# ...

# %%
df.groupby("Name_of_Car")['Original_Price'].max()
# Out:
# Name_of_Car
# Datsun         247000
# Ford           789000
# Honda          766000
# Hyundai       1160000
# Jeep          1373000
# KIA           1800000
# MG            1602000
# Mahindra      1569000
# Maruti         822000
# Nissan         666000
# Renault        869000
# Skoda         1901000
# Tata          1218000
# Toyota        2297000
# Volkswagen     780000
# Name: Original_Price, dtype: int64

# %%
df[(df["Name_of_Car"]=="Maruti")&(df["car_type"]=="1st")]["Original_Price"].max()
# Out:
# 822000

# %%
df[(df["Name_of_Car"]=="Maruti")&(df["car_type"]=="1st")]["Original_Price"].min()
# Out:
# 144000

# %%
df[(df["Name_of_Car"]=="Maruti")&(df["car_type"]=="2nd")]["Original_Price"].max()
# Out:
# 676000

# %%
df[(df["Name_of_Car"]=="Maruti")&(df["car_type"]=="2nd")]["Original_Price"].min()
# Out:
# 156000

# %%
df[(df["Name_of_Car"]=="Maruti")&(df["car_type"]=="3rd")]["Original_Price"].max()
# Out:
# 424000

# %%
df[(df["Name_of_Car"]=="Maruti")&(df["car_type"]=="3rd")]["Original_Price"].min()
# Out:
# 153000

# %%
df
# Out:
#     Name_of_Car  Original_Price  Offer_Price Type_of_Fuel       Ride  Year  \
# 0        Maruti          144000       144000       Petrol     Manual  2010
# 1        Maruti          150000       141000       Petrol     Manual  2010
# 2        Maruti          153000       137000       Petrol     Manual  2010
# 3        Maruti          156000       156000       Petrol     Manual  2011
# 4        Maruti          161000       156000       Petrol     Manual  2011
# ..          ...             ...          ...          ...        ...   ...
# 435          MG         1602000      1541000       Diesel     Manual  2020
# 436         KIA         1734000      1734000       Diesel  Automatic  2022
# 437         KIA         1800000      1800000       Diesel     Manual  2022
# 438       Skoda         1901000      1828000       Petrol  Automatic  2022
# 439      Toyota         2297000      2214000       Diesel  Automatic  2017
#
# ...

# %%
#df.drop(["max"],axis=1,inplace=True)

# %%
df.groupby(["city","Type_of_Fuel"])[["Name_of_Car",'Year']].value_counts()
# Out:
# city      Type_of_Fuel  Name_of_Car  Year
# Agra      Diesel        Maruti       2015    2
#                                      2013    2
#                         Hyundai      2014    1
#                         Maruti       2017    1
#           Petrol        Maruti       2018    2
#                                             ..
# Vadodara  Petrol        Maruti       2012    1
#                                      2010    1
#                         Hyundai      2017    1
#                                      2010    1
#                         Volkswagen   2018    1
# Length: 403, dtype: int64

# %%
df["Original_Price"].corr(df["Offer_Price"])#strong positive relationship,as original price increaces the offer price also \
#increases in a closely related manner
# Out:
# 0.993990746421001

# %%
df["Original_Price"].mean()
# Out:
# 518218.29545454547

# %%
df["Original_Price"].std()#spread of variability,greater variability of
# Out:
# 283671.5786696368

# %%
df["Offer_Price"].std()
# Out:
# 273614.6349353741

# %%
df["Original_Price"].skew()#positively skewed,longer fatter tail on right side,
# Out:
# 1.89154911204167

# %%
df.groupby("Name_of_Car")["EMI(per/month)"].min()
# Out:
# Name_of_Car
# Datsun        2737
# Ford          3503
# Honda         2721
# Hyundai       2315
# Jeep          7539
# KIA           5208
# MG            5990
# Mahindra      3331
# Maruti        2502
# Nissan        4364
# Renault       2018
# Skoda         3081
# Tata          2237
# Toyota        3613
# Volkswagen    4035
# Name: EMI(per/month), dtype: int64

# %%
df.groupby("Name_of_Car")["downpayment"].min()
# Out:
# Name_of_Car
# Datsun         34200
# Ford           91000
# Honda          38400
# Hyundai        25800
# Jeep          217400
# KIA           163400
# MG            308200
# Mahindra      105400
# Maruti         26000
# Nissan         74600
# Renault        41800
# Skoda          63400
# Tata           61000
# Toyota         46200
# Volkswagen     43000
# Name: downpayment, dtype: int64

# %%
pd.pivot_table(df,index="city",columns="Type_of_Fuel",values=["Name_of_Car"],aggfunc=["count"])
# Out:
#                       count
#                 Name_of_Car
# Type_of_Fuel            CNG Diesel Petrol
# city
# Agra                    NaN    6.0   14.0
# Ahmedabad               2.0    4.0   14.0
# Bengaluru               NaN    7.0   12.0
# Chandigarh              NaN    8.0   10.0
# Chennai                 NaN    2.0   17.0
# Coimbatore              NaN    1.0   19.0
# Faridabad               5.0    4.0    9.0
# Ghaziabad               NaN    1.0    1.0
# Gurugram                NaN    3.0    4.0
# Hyderabad               NaN    6.0   14.0
# Kochi                   NaN    6.0   14.0
# Kolkata                 NaN    3.0   17.0
# LasudiaMori             1.0    3.0   16.0
# Lucknow                 1.0    6.0   13.0
# Ludhiana                NaN    1.0    1.0
# Mansarovar              NaN    6.0   14.0
# Mulund                  NaN    3.0    8.0
# Mumbai                  2.0    3.0    4.0
# Nagpur                  2.0    3.0   15.0
# Nasik                   3.0    5.0   12.0
# ...

# %%
df
# Out:
#     Name_of_Car  Original_Price  Offer_Price Type_of_Fuel       Ride  Year  \
# 0        Maruti          144000       144000       Petrol     Manual  2010
# 1        Maruti          150000       141000       Petrol     Manual  2010
# 2        Maruti          153000       137000       Petrol     Manual  2010
# 3        Maruti          156000       156000       Petrol     Manual  2011
# 4        Maruti          161000       156000       Petrol     Manual  2011
# ..          ...             ...          ...          ...        ...   ...
# 435          MG         1602000      1541000       Diesel     Manual  2020
# 436         KIA         1734000      1734000       Diesel  Automatic  2022
# 437         KIA         1800000      1800000       Diesel     Manual  2022
# 438       Skoda         1901000      1828000       Petrol  Automatic  2022
# 439      Toyota         2297000      2214000       Diesel  Automatic  2017
#
#      KM(ran) car_type  EMI(per/month)  downpayment       city
# ...

# %%
df[(df["Original_Price"]<=150000)&(df["Type_of_Fuel"]=="Petrol")&(df["car_type"]=="1st")]
# Out:
#   Name_of_Car  Original_Price  Offer_Price Type_of_Fuel    Ride  Year  \
# 0      Maruti          144000       144000       Petrol  Manual  2010
# 1      Maruti          150000       141000       Petrol  Manual  2010
#
#    KM(ran) car_type  EMI(per/month)  downpayment     city     max
# 0    61662      1st            5693        28800    Patna  822000
# 1    54501      1st            3488        28200  Kolkata  822000

# %%
df
# Out:
#     Name_of_Car  Original_Price  Offer_Price Type_of_Fuel       Ride  Year  \
# 0        Maruti          144000       144000       Petrol     Manual  2010
# 1        Maruti          150000       141000       Petrol     Manual  2010
# 2        Maruti          153000       137000       Petrol     Manual  2010
# 3        Maruti          156000       156000       Petrol     Manual  2011
# 4        Maruti          161000       156000       Petrol     Manual  2011
# ..          ...             ...          ...          ...        ...   ...
# 435          MG         1602000      1541000       Diesel     Manual  2020
# 436         KIA         1734000      1734000       Diesel  Automatic  2022
# 437         KIA         1800000      1800000       Diesel     Manual  2022
# 438       Skoda         1901000      1828000       Petrol  Automatic  2022
# 439      Toyota         2297000      2214000       Diesel  Automatic  2017
#
# ...

# %%
df.groupby("Name_of_Car")["Price_level"].count()
# Out:
# Name_of_Car
# Datsun          8
# Ford            6
# Honda          29
# Hyundai        95
# Jeep            4
# KIA             5
# MG              1
# Mahindra       19
# Maruti        172
# Nissan          4
# Renault        29
# Skoda           8
# Tata           30
# Toyota         13
# Volkswagen     17
# Name: Price_level, dtype: int64

# %%
pd.pivot_table(df,index=["city"],columns=["Name_of_Car"],values=["Price_level"],aggfunc=["count"])
# Out:
#                       count                                                    \
#                 Price_level
# Name_of_Car          Datsun Ford Honda Hyundai Jeep  KIA   MG Mahindra Maruti
# city
# Agra                    NaN  NaN   NaN     6.0  NaN  NaN  NaN      NaN   12.0
# Ahmedabad               1.0  NaN   1.0     9.0  NaN  1.0  NaN      NaN    3.0
# Bengaluru               NaN  NaN   NaN     6.0  NaN  1.0  NaN      NaN    5.0
# Chandigarh              NaN  NaN   NaN     4.0  NaN  NaN  NaN      1.0   10.0
# Chennai                 1.0  1.0   1.0     3.0  NaN  NaN  NaN      2.0    4.0
# Coimbatore              NaN  1.0   3.0     2.0  1.0  NaN  NaN      NaN    5.0
# Faridabad               1.0  NaN   1.0     2.0  1.0  NaN  NaN      1.0    9.0
# Ghaziabad               NaN  NaN   NaN     1.0  1.0  NaN  NaN      NaN    NaN
# Gurugram                NaN  NaN   1.0     NaN  NaN  NaN  NaN      NaN    6.0
# Hyderabad               NaN  1.0   NaN     4.0  NaN  2.0  NaN      2.0    5.0
# ...

# %%
df.groupby("Name_of_Car")['Original_Price'].max()
# Out:
# Name_of_Car
# Datsun         247000
# Ford           789000
# Honda          766000
# Hyundai       1160000
# Jeep          1373000
# KIA           1800000
# MG            1602000
# Mahindra      1569000
# Maruti         822000
# Nissan         666000
# Renault        869000
# Skoda         1901000
# Tata          1218000
# Toyota        2297000
# Volkswagen     780000
# Name: Original_Price, dtype: int64

# %%
g=df.groupby("Name_of_Car")['Original_Price'].max().reset_index()

# %%
plt.title("car v/s maximun original_price")
sns.barplot(x="Name_of_Car",y="Original_Price",data=g)
plt.xticks(rotation=90)
plt.show()

# %%
g
# Out:
#    Name_of_Car  Original_Price
# 0       Datsun          247000
# 1         Ford          789000
# 2        Honda          766000
# 3      Hyundai         1160000
# 4         Jeep         1373000
# 5          KIA         1800000
# 6           MG         1602000
# 7     Mahindra         1569000
# 8       Maruti          822000
# 9       Nissan          666000
# 10     Renault          869000
# 11       Skoda         1901000
# 12        Tata         1218000
# 13      Toyota         2297000
# 14  Volkswagen          780000

# %%
df
# Out:
#     Name_of_Car  Original_Price  Offer_Price Type_of_Fuel       Ride  Year  \
# 0        Maruti          144000       144000       Petrol     Manual  2010
# 1        Maruti          150000       141000       Petrol     Manual  2010
# 2        Maruti          153000       137000       Petrol     Manual  2010
# 3        Maruti          156000       156000       Petrol     Manual  2011
# 4        Maruti          161000       156000       Petrol     Manual  2011
# ..          ...             ...          ...          ...        ...   ...
# 435          MG         1602000      1541000       Diesel     Manual  2020
# 436         KIA         1734000      1734000       Diesel  Automatic  2022
# 437         KIA         1800000      1800000       Diesel     Manual  2022
# 438       Skoda         1901000      1828000       Petrol  Automatic  2022
# 439      Toyota         2297000      2214000       Diesel  Automatic  2017
#
# ...

# %%
a=df.groupby(["Name_of_Car"])["Price_level"].count().reset_index()

# %%
a
# Out:
#    Name_of_Car  Price_level
# 0       Datsun            8
# 1         Ford            6
# 2        Honda           29
# 3      Hyundai           95
# 4         Jeep            4
# 5          KIA            5
# 6           MG            1
# 7     Mahindra           19
# 8       Maruti          172
# 9       Nissan            4
# 10     Renault           29
# 11       Skoda            8
# 12        Tata           30
# 13      Toyota           13
# 14  Volkswagen           17

# %%
sns.barplot(x="Name_of_Car",y="Price_level",data=a)
plt.xticks(rotation=90)
plt.show()

# %%
df
# Out:
#     Name_of_Car  Original_Price  Offer_Price Type_of_Fuel       Ride  Year  \
# 0        Maruti          144000       144000       Petrol     Manual  2010
# 1        Maruti          150000       141000       Petrol     Manual  2010
# 2        Maruti          153000       137000       Petrol     Manual  2010
# 3        Maruti          156000       156000       Petrol     Manual  2011
# 4        Maruti          161000       156000       Petrol     Manual  2011
# ..          ...             ...          ...          ...        ...   ...
# 435          MG         1602000      1541000       Diesel     Manual  2020
# 436         KIA         1734000      1734000       Diesel  Automatic  2022
# 437         KIA         1800000      1800000       Diesel     Manual  2022
# 438       Skoda         1901000      1828000       Petrol  Automatic  2022
# 439      Toyota         2297000      2214000       Diesel  Automatic  2017
#
# ...

# %%
gf=df.groupby(["Name_of_Car","Price_level"])["Ride"].count().reset_index()

# %%
# Out:
#    Name_of_Car Price_level  Ride
# 0       Datsun         Low     8
# 1         Ford         Low     1
# 2         Ford      Medium     5
# 3        Honda         Low    16
# 4        Honda      Medium    13
# 5      Hyundai        High     5
# 6      Hyundai         Low    48
# 7      Hyundai      Medium    42
# 8         Jeep        High     4
# 9          KIA        High     2
# 10         KIA      Medium     1
# 11         KIA   Very High     2
# 12          MG   Very High     1
# 13    Mahindra        High     1
# 14    Mahindra      Medium    16
# 15    Mahindra   Very High     2
# 16      Maruti         Low   108
# 17      Maruti      Medium    64
# 18      Nissan         Low     1
# 19      Nissan      Medium     3
# 20     Renault         Low    23
# 21     Renault      Medium     6
# 22       Skoda        High     1
# 23       Skoda         Low     1
# 24       Skoda      Medium     5
# 25       Skoda   Very High     1
# 26        Tata        High     2
# ...

# %%
sns.barplot(x="Name_of_Car",y="Ride",hue="Price_level",data=gf)
plt.xticks(rotation=90)
plt.show()

# %%
df
# Out:
#     Name_of_Car  Original_Price  Offer_Price Type_of_Fuel       Ride  Year  \
# 0        Maruti          144000       144000       Petrol     Manual  2010
# 1        Maruti          150000       141000       Petrol     Manual  2010
# 2        Maruti          153000       137000       Petrol     Manual  2010
# 3        Maruti          156000       156000       Petrol     Manual  2011
# 4        Maruti          161000       156000       Petrol     Manual  2011
# ..          ...             ...          ...          ...        ...   ...
# 435          MG         1602000      1541000       Diesel     Manual  2020
# 436         KIA         1734000      1734000       Diesel  Automatic  2022
# 437         KIA         1800000      1800000       Diesel     Manual  2022
# 438       Skoda         1901000      1828000       Petrol  Automatic  2022
# 439      Toyota         2297000      2214000       Diesel  Automatic  2017
#
# ...
